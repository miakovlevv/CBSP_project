# %%
from music21 import converter

stream = converter.parse("data/MIDI/raw/35393.mid")

# %%
import sys

sys.path.append("./harmony")

sys.path.append("./tests")

# %%
import importlib

import midi_loader

importlib.reload(midi_loader)
# Out:
# <module 'midi_loader' from 'c:\\Users\\Micha\\CBSP_project\\code\\harmony\\midi_loader.py'>

# %%
path = "data/MIDI/raw/35393.mid"

filename = path.split("/")[-1]
filename
# Out:
# '35393.mid'

# %%
import test_pipeline
importlib.reload(test_pipeline)
from test_pipeline import test_pipeline


test_pipeline(path)
# Out:
# ----- TESTING MIDI LOADER -----
# Loaded 90 notes.
#
# ----- TESTING TXT IMPORT -----
# Extracted 42 chord events.
#
# ----- TESTING KEY DETECTION -----
# Detected key: C major
#
# ----- TESTING HARMONY ANALYSIS -----
# Time:  0.00 | Chord: ['C', 'E', 'C', 'C', 'E', 'C', 'C', 'E', 'C', 'C', 'E', 'C', 'C', 'E', 'C'] | RN: I     | Func: tonic        | Emotion: stable
# Time:  1.00 | Chord: ['C', 'C', 'C', 'C', 'C'] | RN: i     | Func: other        | Emotion: ambiguous
# Time:  2.00 | Chord: ['G', 'C', 'C', 'G', 'C', 'C', 'G', 'C', 'C', 'G', 'C', 'C', 'G', 'C', 'C'] | RN: i5    | Func: other        | Emotion: ambiguous
# Time:  3.00 | Chord: ['G', 'G', 'G', 'G', 'G'] | RN: v     | Func: other        | Emotion: ambiguous
# Time:  4.00 | Chord: ['A', 'C', 'F', 'A', 'C', 'F', 'A', 'C', 'F', 'A', 'C', 'F', 'A', 'C', 'F'] | RN: IV    | Func: tonic        | Emotion: stable
# Time:  5.00 | Chord: ['A', 'A', 'A', 'A', 'A'] | RN: vi    | Func: tonic        | Emotion: stable
# ...
